# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.2
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\r2com\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, intake, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\r2com\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
print(f'request ver {requests.__version__}' )
print('beautifulsoup {}'.format(bs4.__version__))
# Out:
# request ver 2.32.2
# beautifulsoup 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스
req_param = {
    'sid' : 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param) #dict 타입의 값을 넣기 위해 ** 사용
print(url)
# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}
# requests 모듈을 이용해 http 통신
res = requests.get(url, headers=req_header)
print(type(res))
print(res.status_code)
print(res.ok)
if res.ok :
    html = res.text
    #parsing을 하기 위해 BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")
    #print(type(soup))
    #print(len(soup.select("a[]")))
    #print(len(soup.select("div.sa_text a[href*='n.news.naver.com/mnews/article']")))
    #print(len(soup.select("div.sa_text a.sa_text_title")))
    atag_list = soup.select("div.sa_text a.sa_text_title")
    #print(type(atag_list))
    print('-----------------------------')
    for atag in atag_list :
        #print(type(atag))
        #print(atag)
        title = atag.text.strip() #strip()로 공백제거
        url = atag['href']
        print(f'news 제목 = {title}')
        print(f'news 링크 = {url}')
        print('-----------------------------')
# Out:
# https://news.naver.com/section/105
# <class 'requests.models.Response'>
# 200
# True
# -----------------------------
# news 제목 = 게임산업협회, 게임 리터러시 교육 안내서 발간…“이용군 맞춰 체계화”
# news 링크 = https://n.news.naver.com/mnews/article/119/0002858633
# -----------------------------
# news 제목 = SK C&C, 베트남 ICT 기업과 맞손…디지털 ESG 사업 글로벌 확장
# news 링크 = https://n.news.naver.com/mnews/article/277/0005454901
# -----------------------------
# news 제목 = 한국금거래소 “티메프 미정산 이슈, 유동성 영향 없다…매출 영향 미미”
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179207
# -----------------------------
# news 제목 = 저가폰에도 5G·AI 이식…스마트폰 '가성비 경쟁'
# news 링크 = https://n.news.naver.com/mnews/article/011/0004375740
# -----------------------------
# news 제목 = 김성근 포스텍 총장 “우수 교수 정착지원금 10억원으로 확대”
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009858
# -----------------------------
# news 제목 = 더존비즈온, 2분기 매출 994억·영업익 204억
# news 링크 = https://n.news.naver.com/mnews/article/421/0007710646
# -----------------------------
# news 제목 = 카카오헬스케어, 글로벌 ‘연구 협력 네트워크’ 17개 병원으로 확대
# news 링크 = https://n.news.naver.com/mnews/article/011/0004375997
# -----------------------------
# news 제목 = 엔씨소프트, 성장 동력 확보 ‘지속’…빅게임스튜디오에 370억 규모 지분·판권 투자
# news 링크 = https://n.news.naver.com/mnews/article/009/0005345579
# -----------------------------
# news 제목 = 코스피·코스닥 줄이어 서킷브레이커 발동
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340932
# -----------------------------
# news 제목 = 韓, 반도체 대중 수출 늘자… 中 “美 수출 제재 한계 드러나”
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009937
# -----------------------------
# news 제목 = ‘아재 입맛’인 줄 알았는데…믹스커피 MZ 업고 뜨나
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340930
# -----------------------------
# news 제목 = 네이버 '쇼핑 검색광고' 타고 온 '파워적립' 8년 만에 폐지
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805500
# -----------------------------
# news 제목 = 한국 양궁 금메달 5개 '싹쓸이'...비결은?
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340929
# -----------------------------
# news 제목 = [단독] 찜통더위 부른 북태평양 고기압…한중일 손잡고 예측 정확성 높인다
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009933
# -----------------------------
# news 제목 = 곤두박질치는 비트코인…'트럼프 약발' 보단 'R의 공포'
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805497
# -----------------------------
# news 제목 = 이통3사 2분기 합산 영업익 예상 1.3조…전환지원금 타격 적었다
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710549
# -----------------------------
# news 제목 = 배터리 화재 키우는 '열폭주' 억제 방법 찾았다
# news 링크 = https://n.news.naver.com/mnews/article/584/0000028179
# -----------------------------
# news 제목 = 티빙, 토종 OTT 1위 굳히기.. 쿠플, EPL로 만회 나선다
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223409
# -----------------------------
# news 제목 = M7 주가폭락에 실망한 투자자…"인내심 한계 달했다"
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340926
# -----------------------------
# news 제목 = 유라클, 수요예측 경쟁률 1065.8대 1…공모가 2만1000원 확정
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179208
# -----------------------------
# news 제목 = "뭘로 결제했더라"…티메프 환불, 페이·카드 희비 엇갈린다
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805482
# -----------------------------
# news 제목 = 엔씨, 빅게임스튜디오 370억 규모 지분·판권 투자
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710504
# -----------------------------
# news 제목 = 아이폰, 이제야 한국 대우하나…신작 '1차 출시국' 포함된다
# news 링크 = https://n.news.naver.com/mnews/article/015/0005018184
# -----------------------------
# news 제목 = 혼돈의 방송통신위원회와 ‘애국자가 없는 세상’
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340921
# -----------------------------
# news 제목 = 청라 화재서 촉발된 '中 배터리 포비아'…韓 3사 대체 가능성은 [소부장박대리]
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179205
# -----------------------------
# news 제목 = 말라리아·일본뇌염 모기 2배 넘게 급증…가장 확실한 예방법은
# news 링크 = https://n.news.naver.com/mnews/article/421/0007710891
# -----------------------------
# news 제목 = “편의점 알바보다 열악한 처우” 이공계 석박사…연구생활장려금 지급, 숨통 트일까
# news 링크 = https://n.news.naver.com/mnews/article/016/0002345560
# -----------------------------
# news 제목 = 전기차 배터리 열폭주 막을 방법 찾았다
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009912
# -----------------------------
# news 제목 = "美 상무부, 자율주행차 중국SW 사용 금지 규정 이달 발표 예정"
# news 링크 = https://n.news.naver.com/mnews/article/029/0002892817
# -----------------------------
# news 제목 = 이공계 대학원생에 매달 80~110만원 지급…연구비 관리제도 개선
# news 링크 = https://n.news.naver.com/mnews/article/001/0014855246
# -----------------------------
# news 제목 = 全 종목 '금메달' 석권 양궁…정의선 회장 40년 함께했다
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340919
# -----------------------------
# news 제목 = "언제까지 이렇게 덥나"…기상청 대신 인기 폭발한 날씨앱
# news 링크 = https://n.news.naver.com/mnews/article/008/0005073035
# -----------------------------
# news 제목 = 美, 자율주행차에 중국산 SW·통신모듈 탑재 금지 추진
# news 링크 = https://n.news.naver.com/mnews/article/011/0004376131
# -----------------------------
# news 제목 = 韓 해킹한 자료로 공장·지방개발 하려는 北... 北해커들 이곳 노린다
# news 링크 = https://n.news.naver.com/mnews/article/008/0005073031
# -----------------------------
# news 제목 = 코오롱바이오텍, 골관절염 치료제 ‘TG-C’ 대량 생산 공정 개발
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805447
# -----------------------------
# news 제목 = “스마트폰 시장 3년 만에 성장세...삼성, 애플과 격차 벌릴 것”
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009904
# -----------------------------
# news 제목 = [제약바이오] 종근당, 바르는 소염진통제 케펨겔 출시 外
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340918
# -----------------------------
# news 제목 = '아마란스10' 200% 늘어난 더존비즈온, 하반기도 맑음
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223355
# -----------------------------
# news 제목 = 더존비즈온, 매출·영업이익 '쑥쑥'…"핵심사업 고른 성장"
# news 링크 = https://n.news.naver.com/mnews/article/648/0000027909
# -----------------------------
# news 제목 = 애플, 버터플라이 키보드 집단소송 美 소비자에 보상금
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009897
# -----------------------------
# news 제목 = ‘살 파먹는 세균’ 잡는 약물 개발 [달콤한 사이언스]
# news 링크 = https://n.news.naver.com/mnews/article/081/0003470020
# -----------------------------
# news 제목 = “이공계 석·박사 월 80~110만 원”…‘한국형 스타이펜드’ 윤곽 나왔다
# news 링크 = https://n.news.naver.com/mnews/article/056/0011775233
# -----------------------------
# news 제목 = 자체 개발 SQL로 승부하는 '스마트마인드' [과기대X글로벌]
# news 링크 = https://n.news.naver.com/mnews/article/020/0003580328
# -----------------------------
# news 제목 = "애플, 9월엔 인텔리전스 없이 아이폰16만 나온다"
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340917
# -----------------------------

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

def print_news(sid, section):    
    # 요청 Parameter
    req_param = {
    'sid': sid
    }
    url = 'https://news.naver.com/section/{sid}'.format(**req_param)
    
    print(f'======> {url} {section} 뉴스 <======')
    
    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }

    # requests 모듈을 이용해 http 통신
    res = requests.get(url, headers=req_header)
    print(type(res))
    print(res.status_code)
    print(res.ok)
    if res.ok :
        html = res.text
        #parsing을 하기 위해 BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        atag_list = soup.select("div.sa_text a.sa_text_title")  #클래스는 .으로 접근
        print('----------------------------------------------------------------')
        for atag in atag_list :
            title = atag.text.strip() #strip()로 공백제거
            url = atag['href'] #태그 내의 속성은 []으로 접근
            print(f'news 제목 = {title}')
            print(f'news 링크 = {url}')
            print('------------------------------------------------------------')

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
print_news(102,section_dict[102])
# Out:
# ======> https://news.naver.com/section/102 사회 뉴스 <======
# <class 'requests.models.Response'>
# 200
# True
# ----------------------------------------------------------------
# news 제목 = 조지호 경찰청장 후보자 청문회 두고 “현안 질의 없어 아쉬워”[경솔한 이야기]
# news 링크 = https://n.news.naver.com/mnews/article/011/0004375619
# ------------------------------------------------------------
# news 제목 = 농식품부 "반려견 등록 필수…9월까지 자진신고"
# news 링크 = https://n.news.naver.com/mnews/article/082/0001282436
# ------------------------------------------------------------
# news 제목 = ‘따릉이 폭주족’ 오늘 서울 시내 집결 예고
# news 링크 = https://n.news.naver.com/mnews/article/056/0011774686
# ------------------------------------------------------------
# news 제목 = ATM에서 4억 훔쳐 산에 묻은 보안 직원...3억 회수
# news 링크 = https://n.news.naver.com/mnews/article/052/0002070275
# ------------------------------------------------------------
# news 제목 = 2025년 최저임금 '1만 30원' 확정…月 209만 6천 원 꼴
# news 링크 = https://n.news.naver.com/mnews/article/079/0003924504
# ------------------------------------------------------------
# news 제목 = 윤 대통령이 “미쳤다”던 검찰 통신조회, 이번엔 3천명이라는데… [8월5일 뉴스뷰리핑]
# news 링크 = https://n.news.naver.com/mnews/article/028/0002701275
# ------------------------------------------------------------
# news 제목 = 검찰, 티몬·위메프·큐텐 3차 압수수색
# news 링크 = https://n.news.naver.com/mnews/article/016/0002345507
# ------------------------------------------------------------
# news 제목 = 필리핀 가사관리사 내일 입국…다음 달부터 투입
# news 링크 = https://n.news.naver.com/mnews/article/056/0011775218
# ------------------------------------------------------------
# news 제목 = 군인권센터, '임성근 명예전역 반대' 서명 제출...경찰과 1시간 반 대치
# news 링크 = https://n.news.naver.com/mnews/article/052/0002070306
# ------------------------------------------------------------
# news 제목 = 대한항공 인천-울란바토르 항공편 승객·승무원 14명, 난기류에 경상
# news 링크 = https://n.news.naver.com/mnews/article/214/0001365857
# ------------------------------------------------------------
# news 제목 = 조선대학교 캠퍼스에 '낙뢰'…길가던 30대 심정지 상태로 병원 이송
# news 링크 = https://n.news.naver.com/mnews/article/031/0000859393
# ------------------------------------------------------------
# news 제목 = ‘청라 아파트 화재’ 전기차, 59시간 동안 주차된 상태서 폭발
# news 링크 = https://n.news.naver.com/mnews/article/081/0003470077
# ------------------------------------------------------------
# news 제목 = 전북 11개 시‧군 호우특보…많은 곳 50mm 비
# news 링크 = https://n.news.naver.com/mnews/article/079/0003924764
# ------------------------------------------------------------
# news 제목 = 대학교서 연수 30대 교사 낙뢰 맞고 심정지상태 병원 이송(종합)
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711065
# ------------------------------------------------------------
# news 제목 = [단독] 경찰, '집게손 피해자' 고소 각하...이유 황당
# news 링크 = https://n.news.naver.com/mnews/article/047/0002442019
# ------------------------------------------------------------
# news 제목 = 이란 보복 초읽기… 바이든, 백악관 안보회의 소집
# news 링크 = https://n.news.naver.com/mnews/article/656/0000100162
# ------------------------------------------------------------
# news 제목 = 부산 폭염경보 속 행복주택 신청자 대기하다 실신…항의 빗발
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711057
# ------------------------------------------------------------
# news 제목 = 폭염에 리어카 끌며 땀 뻘뻘… 폐지 노인 도운 해병 눈길
# news 링크 = https://n.news.naver.com/mnews/article/023/0003850631
# ------------------------------------------------------------
# news 제목 = [르포] "이 더위에 단수라니"…'양동이 급수 지원' 받는 청도군 주민들
# news 링크 = https://n.news.naver.com/mnews/article/001/0014855465
# ------------------------------------------------------------
# news 제목 = 유흥업소 ‘여친’, 친구가 퇴근 안 시키자…야구방망이 들고 간 ‘조폭’
# news 링크 = https://n.news.naver.com/mnews/article/081/0003470075
# ------------------------------------------------------------
# news 제목 = "낙뢰 떨어져 감전"…30대 남성 의식 잃어
# news 링크 = https://n.news.naver.com/mnews/article/079/0003924760
# ------------------------------------------------------------
# news 제목 = '수영복 차림 여성' 노린 '해수욕장 몰카' 범죄 잇따라
# news 링크 = https://n.news.naver.com/mnews/article/659/0000024155
# ------------------------------------------------------------
# news 제목 = 산부인과서 시술받던 20대 여성 심정지…의료과실 여부 조사
# news 링크 = https://n.news.naver.com/mnews/article/001/0014855448
# ------------------------------------------------------------
# news 제목 = 필리핀 가사관리사 내일 입국···‘돌봄-가사’ 업무범위 논란 여전
# news 링크 = https://n.news.naver.com/mnews/article/032/0003313002
# ------------------------------------------------------------
# news 제목 = 달달 외워선 9급 공무원 못 된다… 내년 예시 문제 이렇게
# news 링크 = https://n.news.naver.com/mnews/article/081/0003470074
# ------------------------------------------------------------
# news 제목 = “여친 당장 퇴근시켜라”…친구 차 부수고 폭행한 20대 男, 징역형
# news 링크 = https://n.news.naver.com/mnews/article/020/0003580346
# ------------------------------------------------------------
# news 제목 = 전국 곳곳에서 천둥·번개 동반 강한 소나기···중대본 1단계 가동
# news 링크 = https://n.news.naver.com/mnews/article/032/0003313001
# ------------------------------------------------------------
# news 제목 = 공모조건과 취지 “문경이 딱이네” 제2중앙경찰학교 유치 나선 문경시
# news 링크 = https://n.news.naver.com/mnews/article/088/0000896181
# ------------------------------------------------------------
# news 제목 = 탁송 중 전기차서 갑자기 불 ‘활활’…“누구한테 보상받나”(영상)
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805506
# ------------------------------------------------------------
# news 제목 = 전주 '호우주의보→호우경보'…오늘 최대 80㎜ 쏟아진다
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710601
# ------------------------------------------------------------
# news 제목 = [1번지이슈] 곧 입추인데 연일 폭염…"야외 활동 자제해야"
# news 링크 = https://n.news.naver.com/mnews/article/422/0000674752
# ------------------------------------------------------------
# news 제목 = 대낮 낙뢰 맞고 쓰러진 30대 심정지…대학 캠퍼스 걷다 날벼락
# news 링크 = https://n.news.naver.com/mnews/article/008/0005073090
# ------------------------------------------------------------
# news 제목 = 광주·전남 호우특보 확대…장성에 시간당 60㎜ 비(종합)
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710599
# ------------------------------------------------------------
# news 제목 = "임성근 전 사단장 명예전역 반대" 국민 2만명 서명
# news 링크 = https://n.news.naver.com/mnews/article/469/0000816136
# ------------------------------------------------------------
# news 제목 = 포항제철소 4고로 개보수, 포스코는 '천국' 협력업체는 '지옥'
# news 링크 = https://n.news.naver.com/mnews/article/088/0000896180
# ------------------------------------------------------------
# news 제목 = "국민의힘, 중앙당 구조조정하고 지구당 부활해야"
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711037
# ------------------------------------------------------------
# news 제목 = 술에 취해 동료 경찰 폭행 혐의 경정급 간부 입건
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711035
# ------------------------------------------------------------
# news 제목 = “전기차 화재로 뭔 고생” 청라 단전·단수에 분진피해까지[르포]
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805502
# ------------------------------------------------------------
# news 제목 = 경북 동해안, 독성 있는 해파리떼 습격 '비상'...피서객 쏘임·어업 피해 막심
# news 링크 = https://n.news.naver.com/mnews/article/088/0000896178
# ------------------------------------------------------------
# news 제목 = [성금내역] 암투병에 홀로 3남매 양육하는 민세빈 씨에 2,614만원 전달
# news 링크 = https://n.news.naver.com/mnews/article/088/0000896177
# ------------------------------------------------------------
# news 제목 = [속보]카이스트 대학원생 주도, SKY 명문대생 등 모인 '마약 동아리' 적발
# news 링크 = https://n.news.naver.com/mnews/article/087/0001060085
# ------------------------------------------------------------
# news 제목 = 청라 전기차 화재 원인 감식…경찰 “외부 충격 없었다”
# news 링크 = https://n.news.naver.com/mnews/article/016/0002345600
# ------------------------------------------------------------
# news 제목 = 서울교육청, 교장·교감·교육전문직 등 478명 정기인사
# news 링크 = https://n.news.naver.com/mnews/article/001/0014855428
# ------------------------------------------------------------
# news 제목 = 사람 잡는 공포의 폭염…정부, 사상 첫 상황관리관 급파(종합2보)
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710578
# ------------------------------------------------------------
# news 제목 = 서울시 긴급신고용 안심벨 ‘헬프미’ 100분만에 신청 마감…인기비결은 ‘기능+디자인+무료’
# news 링크 = https://n.news.naver.com/mnews/article/016/0002345598
# ------------------------------------------------------------
# news 제목 = 65년 뒤 알게된 군인 아버지 사인...법원 “군, 보상금 지급해야”
# news 링크 = https://n.news.naver.com/mnews/article/081/0003470069
# ------------------------------------------------------------

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=798173&no=5&amp;weekday=thu'
}
img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
import os

url = 'https://comic.naver.com/webtoon/detail?titleId=817945&no=37&week=mon'
req_header = {
    'referer': url
}
res = requests.get(url)
if res.ok: #200
    pass
else:
    print(res.status_code)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %% [markdown]
# ### 4. 단축 URL 생성하는 Open API 사용하기
# * urllib 사용

# %%
import os
import sys
import urllib.request

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값
encText = urllib.parse.quote("https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-")
data = "url=" + encText
url = "https://openapi.naver.com/v1/util/shorturl"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값

origin_url = "https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-"

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': 'V',
    'X-Naver-Client-Secret': 'y_',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

res = requests.get(url, params=payload, headers=headers)
items_data = res.json()['items']
#print(items_data)

items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])

    items_list.append(item_list)
    item_list = []

print(items_list)

with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
